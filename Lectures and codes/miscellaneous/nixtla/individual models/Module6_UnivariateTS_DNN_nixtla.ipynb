# %% [markdown]
# ### Prof. Pedram Jahangiry - Nixtla Version
#
# This notebook demonstrates time series forecasting using **Nixtla's NeuralForecast** library with the **MLP model**.
#
# ![logo](https://upload.wikimedia.org/wikipedia/commons/4/44/Huntsman-Wordmark-with-USU-Blue.gif#center)
#
# ## 🔗 Links
#
# [![linkedin](https://img.shields.io/badge/LinkedIn-0A66C2?style=for-the-badge&logo=linkedin&logoColor=white)](https://www.linkedin.com/in/pedram-jahangiry-cfa-5778015a)
#
# [![Youtube](https://img.shields.io/badge/youtube_channel-1DA1F2?style=for-the-badge&logo=youtube&logoColor=white&color=FF0000)](https://www.youtube.com/channel/UCNDElcuuyX-2pSatVBDpJJQ)
#
# [![Twitter URL](https://img.shields.io/twitter/url/https/twitter.com/PedramJahangiry.svg?style=social&label=Follow%20%40PedramJahangiry)](https://twitter.com/PedramJahangiry)
#
# ---

# %% [markdown]
# # Module 6 - Deep Neural Networks with Nixtla NeuralForecast

# %% [markdown]
# # Installation
#
# You need to install the `neuralforecast` package:
#
# ```bash
# pip install neuralforecast
# ```
#
# For more information, visit: https://nixtlaverse.nixtla.io/neuralforecast/

# %%
# Install neuralforecast if not already installed
# !pip install neuralforecast

# check the version of neuralforecast
import neuralforecast
print(neuralforecast.__version__)  # should be 1.5.0 or higher
# Out:
# 3.1.7

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

from neuralforecast import NeuralForecast
from neuralforecast.models import MLP
from neuralforecast.losses.pytorch import  MSE

# %% [markdown]
# ## Load and Prepare Data
#
# NeuralForecast requires data in a specific format with columns:
# - `unique_id`: Identifier for each time series
# - `ds`: Timestamp
# - `y`: Target variable

# %%
# Load data
data = pd.read_csv("https://raw.githubusercontent.com/PJalgotrader/Deep_forecasting-USU/main/data/airline_passengers.csv")
data.columns = ['ds', 'y']
data['ds'] = pd.to_datetime(data['ds'])
data['unique_id'] = 'airline'  # Add unique_id column required by NeuralForecast

# Reorder columns to match NeuralForecast format
data = data[['unique_id', 'ds', 'y']]
data.head()
# Out:
#   unique_id         ds    y
# 0   airline 1949-01-01  112
# 1   airline 1949-02-01  118
# 2   airline 1949-03-01  132
# 3   airline 1949-04-01  129
# 4   airline 1949-05-01  121

# %%
# Visualize the full dataset
plt.figure(figsize=(12, 5))
plt.plot(data['ds'], data['y'])
plt.title('Airline Passengers Time Series')
plt.xlabel('Date')
plt.ylabel('Number of Passengers')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Train-Test Split

# %%
# Define test period
test_period = 24
train_period = len(data) - test_period

print(f"Train period: {train_period}")
print(f"Test period: {test_period}")

# Split data
train = data.iloc[:train_period]
test = data.iloc[train_period:]

# Visualize train and test split
plt.figure(figsize=(12, 5))
plt.plot(train['ds'], train['y'], label='Train')
plt.plot(test['ds'], test['y'], label='Test')
plt.title('Train and Test Data Split')
plt.xlabel('Date')
plt.ylabel('Number of Passengers')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Train period: 120
# Test period: 24

# %% [markdown]
# ## MLP Model Configuration
#
# We'll use NeuralForecast's MLP (Multi-Layer Perceptron) model. The MLP model is a simple feedforward neural network similar to the DNN in the original notebook.
#
# Key parameters:
# - `h`: Forecast horizon (number of steps to predict)
# - `input_size`: Number of lagged observations to use as input (similar to Tx)
# - `num_layers`: Number of hidden layers
# - `hidden_size`: Size of hidden layers
# - `max_steps`: Maximum number of training steps (epochs)
# - `scaler_type`: Type of scaling to apply to the data

# %%
# Model parameters
horizon = 1  # For one-step ahead forecasting
input_size = 12  # Number of lags (similar to Tx in original notebook)

# Initialize MLP model
models = [
    MLP(
        h=horizon,
        input_size=input_size,
        num_layers=2,
        hidden_size=32,
        loss=MSE(),
        max_steps=100,
        scaler_type='standard',
        #early_stop_patience_steps=5,
        batch_size=16,
        random_seed=42
    )
]
# Out:
# Seed set to 42

# %% [markdown]
# ## Train the Model

# %%
# Initialize NeuralForecast
nf = NeuralForecast(models=models, freq='MS')  # MS = Month Start frequency

# Fit the model on training data
# NeuralForecast will automatically use the last 'input_size' values for validation
nf.fit(df=train)
print("Model training complete!")
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
#
#   | Name         | Type          | Params | Mode  | FLOPs
# ---------------------------------------------------------------
# 0 | loss         | MSE           | 0      | train | 0
# 1 | padder_train | ConstantPad1d | 0      | train | 0
# 2 | scaler       | TemporalNorm  | 0      | train | 0
# 3 | mlp          | ModuleList    | 1.5 K  | train | 0
# 4 | out          | Linear        | 33     | train | 0
# ---------------------------------------------------------------
# 1.5 K     Trainable params
# 0         Non-trainable params
# 1.5 K     Total params
# 0.006     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 40.50it/s, v_num=0, train_loss_step=0.162, train_loss_epoch=0.162]
# `Trainer.fit` stopped: `max_steps=100` reached.
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 36.61it/s, v_num=0, train_loss_step=0.162, train_loss_epoch=0.162]
# Model training complete!

# %% [markdown]
# ## One-Step Ahead Forecasting
#
# For one-step ahead forecasting, we predict one step at a time using actual historical values.

# %%
# Make predictions on the test set (one-step ahead)
# We'll use cross-validation style prediction to get one-step forecasts
test_predictions = []

for i in range(len(test)):
    # Use all data up to current point
    current_train = data.iloc[:train_period + i]

    # Predict next step
    forecast = nf.predict(df=current_train)
    test_predictions.append(forecast['MLP'].values[0])

# Add predictions to dataframe
data['MLP_1step_forecast'] = np.nan
data.loc[train_period:, 'MLP_1step_forecast'] = test_predictions

print("One-step ahead forecasting complete!")
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 17.15it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 148.44it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 153.54it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 140.71it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 167.59it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 158.63it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 149.54it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 172.41it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 174.64it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 148.37it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 130.23it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 185.78it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 125.53it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 127.58it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 128.49it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 205.12it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 224.82it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 220.47it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 241.48it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 230.53it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 233.03it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 164.67it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 179.44it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 174.36it/s]
# One-step ahead forecasting complete!

# %%
# Visualize one-step ahead forecast
plt.figure(figsize=(15, 5))
plt.plot(data['ds'], data['y'], label='Actual', linewidth=1)
plt.plot(data.iloc[train_period:]['ds'], data.iloc[train_period:]['MLP_1step_forecast'],
         label='1-step Forecast', linestyle='--')
plt.axvline(x=data.iloc[train_period]['ds'], color='red', linestyle='--', alpha=0.5, label='Train/Test Split')
plt.title('One-Step Ahead Forecast')
plt.xlabel('Date')
plt.ylabel('Number of Passengers')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Multi-Step Forecasting
#
# For multi-step forecasting, we predict iteratively, using previous predictions as inputs.

# %%
# Re-train model on full training data
nf_multistep = NeuralForecast(models=models, freq='MS')
nf_multistep.fit(df=train)

# Multi-step forecast: predict iteratively
multistep_predictions = []
current_data = train.copy()

for i in range(test_period):
    # Predict next step
    forecast = nf_multistep.predict(df=current_data)
    next_pred = forecast['MLP'].values[0]
    multistep_predictions.append(next_pred)

    # Add prediction to data for next iteration
    next_row = pd.DataFrame({
        'unique_id': ['airline'],
        'ds': [current_data['ds'].iloc[-1] + pd.DateOffset(months=1)],
        'y': [next_pred]
    })
    current_data = pd.concat([current_data, next_row], ignore_index=True)

# Add multi-step predictions to dataframe
data['MLP_multistep_forecast'] = np.nan
data.loc[train_period:, 'MLP_multistep_forecast'] = multistep_predictions

print("Multi-step forecasting complete!")
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
#
#   | Name         | Type          | Params | Mode  | FLOPs
# ---------------------------------------------------------------
# 0 | loss         | MSE           | 0      | train | 0
# 1 | padder_train | ConstantPad1d | 0      | train | 0
# 2 | scaler       | TemporalNorm  | 0      | train | 0
# 3 | mlp          | ModuleList    | 1.5 K  | train | 0
# 4 | out          | Linear        | 33     | train | 0
# ---------------------------------------------------------------
# 1.5 K     Trainable params
# 0         Non-trainable params
# 1.5 K     Total params
# 0.006     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 36.40it/s, v_num=2, train_loss_step=0.162, train_loss_epoch=0.162]
# `Trainer.fit` stopped: `max_steps=100` reached.
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 33.72it/s, v_num=2, train_loss_step=0.162, train_loss_epoch=0.162]
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 157.18it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 128.07it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 109.24it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 167.90it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 147.56it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 162.05it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 172.20it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 158.35it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 139.51it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 141.81it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 180.25it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 156.91it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 200.80it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 142.59it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 157.31it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 145.77it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 156.00it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 147.26it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 156.03it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 161.66it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 136.61it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 186.66it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 167.23it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 138.33it/s]
# Multi-step forecasting complete!

# %%
# Visualize one-step and multi-step forecasts
plt.figure(figsize=(15, 5))
plt.plot(data['ds'], data['y'], label='Actual', linewidth=1)
plt.plot(data.iloc[train_period:]['ds'], data.iloc[train_period:]['MLP_1step_forecast'],
         label='1-step Forecast', linestyle='--')
plt.plot(data.iloc[train_period:]['ds'], data.iloc[train_period:]['MLP_multistep_forecast'],
         label='Multi-step Forecast', linestyle='--')
plt.axvline(x=data.iloc[train_period]['ds'], color='red', linestyle='--', alpha=0.5, label='Train/Test Split')
plt.title('One-Step vs Multi-Step Forecast')
plt.xlabel('Date')
plt.ylabel('Number of Passengers')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Multi-Output Forecasting
#
# For multi-output forecasting, we configure the model to predict all future values at once by setting `h=test_period`.

# %%
# Initialize MLP model for multi-output forecasting
horizon_multi = test_period  # Predict all test periods at once

models_multi = [
    MLP(
        h=horizon_multi,
        input_size=input_size,
        num_layers=2,
        hidden_size=32,
        loss=MSE(),
        max_steps=200,
        scaler_type='standard',
        batch_size=16,
        random_seed=42
    )
]

# Train model for multi-output
nf_multi = NeuralForecast(models=models_multi, freq='MS')
nf_multi.fit(df=train)

# Make multi-output prediction
forecast_multi = nf_multi.predict(df=train)

# Add multi-output predictions to dataframe
data['MLP_multioutput_forecast'] = np.nan
data.loc[train_period:, 'MLP_multioutput_forecast'] = forecast_multi['MLP'].values

print("Multi-output forecasting complete!")
# Out:
# Seed set to 42
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
#
#   | Name         | Type          | Params | Mode  | FLOPs
# ---------------------------------------------------------------
# 0 | loss         | MSE           | 0      | train | 0
# 1 | padder_train | ConstantPad1d | 0      | train | 0
# 2 | scaler       | TemporalNorm  | 0      | train | 0
# 3 | mlp          | ModuleList    | 1.5 K  | train | 0
# 4 | out          | Linear        | 792    | train | 0
# ---------------------------------------------------------------
# 2.3 K     Trainable params
# 0         Non-trainable params
# 2.3 K     Total params
# 0.009     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# Epoch 199: 100%|██████████| 1/1 [00:00<00:00, 36.98it/s, v_num=4, train_loss_step=0.622, train_loss_epoch=0.622]
# `Trainer.fit` stopped: `max_steps=200` reached.
# Epoch 199: 100%|██████████| 1/1 [00:00<00:00, 33.28it/s, v_num=4, train_loss_step=0.622, train_loss_epoch=0.622]
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 28.98it/s]
# Multi-output forecasting complete!

# %%
# Visualize all three forecast types
plt.figure(figsize=(15, 5))
plt.plot(data['ds'], data['y'], label='Actual', linewidth=1)
plt.plot(data.iloc[train_period:]['ds'], data.iloc[train_period:]['MLP_1step_forecast'],
         label='1-step Forecast', linestyle='--', alpha=0.7)
plt.plot(data.iloc[train_period:]['ds'], data.iloc[train_period:]['MLP_multistep_forecast'],
         label='Multi-step Forecast', linestyle='--', alpha=0.7)
plt.plot(data.iloc[train_period:]['ds'], data.iloc[train_period:]['MLP_multioutput_forecast'],
         label='Multi-output Forecast', linestyle='--')
plt.axvline(x=data.iloc[train_period]['ds'], color='red', linestyle='--', alpha=0.5, label='Train/Test Split')
plt.title('Comparison: 1-step, Multi-step, and Multi-output Forecasts')
plt.xlabel('Date')
plt.ylabel('Number of Passengers')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Forecast Comparison using MAPE

# %%
# Define MAPE function
def mean_absolute_percentage_error(y_true, y_pred):
    """
    Calculate Mean Absolute Percentage Error (MAPE)
    """
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
# Calculate MAPE for each forecast type
actual_test = data.loc[train_period:, 'y'].values

mape_1step = mean_absolute_percentage_error(actual_test, data.loc[train_period:, 'MLP_1step_forecast'])
mape_multistep = mean_absolute_percentage_error(actual_test, data.loc[train_period:, 'MLP_multistep_forecast'])
mape_multioutput = mean_absolute_percentage_error(actual_test, data.loc[train_period:, 'MLP_multioutput_forecast'])

print("=" * 50)
print("MAPE Comparison")
print("=" * 50)
print(f"1-step forecast MAPE:      {mape_1step:.4f}%")
print(f"Multi-step forecast MAPE:  {mape_multistep:.4f}%")
print(f"Multi-output forecast MAPE: {mape_multioutput:.4f}%")
print("=" * 50)
# Out:
# ==================================================
# MAPE Comparison
# ==================================================
# 1-step forecast MAPE:      3.6426%
# Multi-step forecast MAPE:  7.0528%
# Multi-output forecast MAPE: 9.6496%
# ==================================================

# %%
# Create comparison dataframe
comparison_df = pd.DataFrame({
    'Forecast Type': ['1-step', 'Multi-step', 'Multi-output'],
    'MAPE': [mape_1step, mape_multistep, mape_multioutput]
})

comparison_df
# Out:
#   Forecast Type      MAPE
# 0        1-step  3.642582
# 1    Multi-step  7.052755
# 2  Multi-output  9.649595

# %%
# Visualize MAPE comparison
plt.figure(figsize=(10, 6))
plt.bar(comparison_df['Forecast Type'], comparison_df['MAPE'], color=['blue', 'orange', 'green'])
plt.title('MAPE Comparison Across Forecast Types')
plt.ylabel('MAPE')
plt.xlabel('Forecast Type')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ## NeuralForecast MLP Forecaster Function
#
# Similar to the `dl_ts_forecaster` function in the original notebook, here's a wrapper function for easy forecasting with NeuralForecast MLP.

# %%
def mlp_ts_forecaster(data, target='y', lags=12, fh=12, unique_id='series1', freq='MS',
                      max_steps=100, hidden_size=32, num_layers=2):
    """
    Time series forecasting using Nixtla's NeuralForecast MLP model.

    Parameters:
    -----------
    data : pd.DataFrame
        Input dataframe with date index and target column
    target : str
        Name of target column to forecast
    lags : int
        Number of lagged observations to use as input
    fh : int
        Forecast horizon (number of steps ahead)
    unique_id : str
        Identifier for the time series
    freq : str
        Frequency of the time series (e.g., 'MS' for month start)
    max_steps : int
        Maximum training steps
    hidden_size : int
        Size of hidden layers
    num_layers : int
        Number of hidden layers

    Returns:
    --------
    pd.DataFrame
        Original dataframe with forecast columns added
    """

    # Prepare data in NeuralForecast format
    df = data.copy()
    if 'ds' not in df.columns:
        df = df.reset_index()
        df.columns = ['ds', target]

    df['unique_id'] = unique_id
    df = df.rename(columns={target: 'y'})
    df = df[['unique_id', 'ds', 'y']]

    # Train-test split
    train_period = len(df) - fh
    train = df.iloc[:train_period]

    print(f"Training period: {train_period}, Test period: {fh}")

    # Initialize models
    models_1step = [
        MLP(h=1, input_size=lags, num_layers=num_layers, hidden_size=hidden_size,
            loss=MSE(), max_steps=max_steps, scaler_type='standard',
            batch_size=16, random_seed=42)
    ]

    models_multi = [
        MLP(h=fh, input_size=lags, num_layers=num_layers, hidden_size=hidden_size,
            loss=MSE(), max_steps=max_steps*2, scaler_type='standard',
            batch_size=16, random_seed=42)
    ]

    # 1-step ahead forecasting
    print("\nTraining 1-step ahead model...")
    nf_1step = NeuralForecast(models=models_1step, freq=freq)
    nf_1step.fit(df=train)

    predictions_1step = []
    for i in range(fh):
        current_train = df.iloc[:train_period + i]
        forecast = nf_1step.predict(df=current_train)
        predictions_1step.append(forecast['MLP'].values[0])

    # Multi-step forecasting
    print("Generating multi-step forecast...")
    multistep_predictions = []
    current_data = train.copy()

    for i in range(fh):
        forecast = nf_1step.predict(df=current_data)
        next_pred = forecast['MLP'].values[0]
        multistep_predictions.append(next_pred)

        next_row = pd.DataFrame({
            'unique_id': [unique_id],
            'ds': [current_data['ds'].iloc[-1] + pd.DateOffset(months=1)],
            'y': [next_pred]
        })
        current_data = pd.concat([current_data, next_row], ignore_index=True)

    # Multi-output forecasting
    print("Training multi-output model...")
    nf_multi = NeuralForecast(models=models_multi, freq=freq)
    nf_multi.fit(df=train)
    forecast_multi = nf_multi.predict(df=train)

    # Add predictions to dataframe
    df['MLP_1step_forecast'] = np.nan
    df['MLP_multistep_forecast'] = np.nan
    df['MLP_multioutput_forecast'] = np.nan

    df.loc[train_period:, 'MLP_1step_forecast'] = predictions_1step
    df.loc[train_period:, 'MLP_multistep_forecast'] = multistep_predictions
    df.loc[train_period:, 'MLP_multioutput_forecast'] = forecast_multi['MLP'].values

    # Calculate MAPE
    actual = df.loc[train_period:, 'y'].values
    mape_1step = mean_absolute_percentage_error(actual, df.loc[train_period:, 'MLP_1step_forecast'])
    mape_multistep = mean_absolute_percentage_error(actual, df.loc[train_period:, 'MLP_multistep_forecast'])
    mape_multioutput = mean_absolute_percentage_error(actual, df.loc[train_period:, 'MLP_multioutput_forecast'])

    print("\n" + "="*50)
    print("MAPE Results")
    print("="*50)
    print(f"1-step MAPE:      {mape_1step:.4f}%")
    print(f"Multi-step MAPE:  {mape_multistep:.4f}%")
    print(f"Multi-output MAPE: {mape_multioutput:.4f}%")
    print("="*50)

    # Plot
    plt.figure(figsize=(15, 5))
    plt.plot(df['ds'], df['y'], label='Actual', linewidth=1)
    plt.plot(df.iloc[train_period:]['ds'], df.iloc[train_period:]['MLP_1step_forecast'],
             label='1-step Forecast', linestyle='--', alpha=0.7)
    plt.plot(df.iloc[train_period:]['ds'], df.iloc[train_period:]['MLP_multistep_forecast'],
             label='Multi-step Forecast', linestyle='--', alpha=0.7)
    plt.plot(df.iloc[train_period:]['ds'], df.iloc[train_period:]['MLP_multioutput_forecast'],
             label='Multi-output Forecast', linestyle='--',  alpha=0.7)
    plt.axvline(x=df.iloc[train_period]['ds'], color='red', linestyle='--', alpha=0.5, label='Train/Test Split')
    plt.title('MLP Forecasts Comparison')
    plt.xlabel('Date')
    plt.ylabel(target)
    plt.legend()
    plt.grid(True)
    plt.show()

    return df

# %% [markdown]
# ## Test the Forecaster Function

# %%
# Load fresh data
df_test = pd.read_csv("https://raw.githubusercontent.com/PJalgotrader/Deep_forecasting-USU/main/data/airline_passengers.csv",
                      index_col="Month", parse_dates=True)

# Run the forecaster
result = mlp_ts_forecaster(df_test, target='Passengers', lags=24, fh=12, freq='MS')
# Out:
# Seed set to 42
# Seed set to 42
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
#
#   | Name         | Type          | Params | Mode  | FLOPs
# ---------------------------------------------------------------
# 0 | loss         | MSE           | 0      | train | 0
# 1 | padder_train | ConstantPad1d | 0      | train | 0
# 2 | scaler       | TemporalNorm  | 0      | train | 0
# 3 | mlp          | ModuleList    | 1.9 K  | train | 0
# 4 | out          | Linear        | 33     | train | 0
# ---------------------------------------------------------------
# 1.9 K     Trainable params
# 0         Non-trainable params
# 1.9 K     Total params
# 0.008     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# Training period: 132, Test period: 12
#
# Training 1-step ahead model...
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 63.67it/s, v_num=6, train_loss_step=0.0793, train_loss_epoch=0.0793]
# `Trainer.fit` stopped: `max_steps=100` reached.
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 56.64it/s, v_num=6, train_loss_step=0.0793, train_loss_epoch=0.0793]
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 46.58it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 234.58it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 241.73it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 222.17it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 241.32it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 235.28it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 223.68it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 243.01it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 225.13it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 235.52it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 235.69it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 239.77it/s]
# Generating multi-step forecast...
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 228.73it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 229.74it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 231.32it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 233.91it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 239.58it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 225.22it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 224.35it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 229.56it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 231.64it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 221.53it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 229.98it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 216.54it/s]
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Training multi-output model...
#   | Name         | Type          | Params | Mode  | FLOPs
# ---------------------------------------------------------------
# 0 | loss         | MSE           | 0      | train | 0
# 1 | padder_train | ConstantPad1d | 0      | train | 0
# 2 | scaler       | TemporalNorm  | 0      | train | 0
# 3 | mlp          | ModuleList    | 1.9 K  | train | 0
# 4 | out          | Linear        | 396    | train | 0
# ---------------------------------------------------------------
# 2.3 K     Trainable params
# 0         Non-trainable params
# 2.3 K     Total params
# 0.009     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# Epoch 199: 100%|██████████| 1/1 [00:00<00:00, 34.62it/s, v_num=8, train_loss_step=0.257, train_loss_epoch=0.257]
# `Trainer.fit` stopped: `max_steps=200` reached.
# Epoch 199: 100%|██████████| 1/1 [00:00<00:00, 30.70it/s, v_num=8, train_loss_step=0.257, train_loss_epoch=0.257]
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 146.80it/s]
#
# ==================================================
# MAPE Results
# ==================================================
# 1-step MAPE:      3.5326%
# Multi-step MAPE:  4.9576%
# Multi-output MAPE: 4.6806%
# ==================================================

# %%
# View results
result.tail(15)
# Out:
#     unique_id         ds    y  MLP_1step_forecast  MLP_multistep_forecast  \
# 129   series1 1959-10-01  407                 NaN                     NaN
# 130   series1 1959-11-01  362                 NaN                     NaN
# 131   series1 1959-12-01  405                 NaN                     NaN
# 132   series1 1960-01-01  417          418.451050              418.451050
# 133   series1 1960-02-01  391          406.166229              406.660706
# 134   series1 1960-03-01  419          459.488159              465.876648
# 135   series1 1960-04-01  461          453.303101              465.248535
# 136   series1 1960-05-01  472          463.768127              471.810211
# 137   series1 1960-06-01  535          555.193665              557.844543
# 138   series1 1960-07-01  622          635.108093              649.938354
# 139   series1 1960-08-01  606          634.933105              656.639648
# 140   series1 1960-09-01  508          536.339600              561.520996
# 141   series1 1960-10-01  461          444.909210              469.236206
# 142   series1 1960-11-01  390          404.672363              421.972168
# 143   series1 1960-12-01  432          425.087097              455.113647
#
#      MLP_multioutput_forecast
# 129                       NaN
# 130                       NaN
# 131                       NaN
# 132                417.812897
# 133                428.513306
# 134                452.013336
# 135                459.773682
# 136                497.537170
# 137                560.400879
# 138                634.313782
# 139                628.407471
# 140                559.798767
# 141                473.797485
# 142                423.681946
# 143                435.405121

# %% [markdown]
# ## Test with Log-Transformed Data

# %%
# Load data and apply log transformation
df_log = pd.read_csv("https://raw.githubusercontent.com/PJalgotrader/Deep_forecasting-USU/main/data/airline_passengers.csv",
                     index_col="Month", parse_dates=True)
df_log['log_Passengers'] = np.log(df_log['Passengers'])

# Select only the log-transformed column for forecasting
df_log_forecast = df_log[['log_Passengers']].copy()

# Run forecaster on log-transformed data
result_log = mlp_ts_forecaster(df_log_forecast, target='log_Passengers', lags=12, fh=12, freq='MS')
# Out:
# Seed set to 42
# Seed set to 42
# Training period: 132, Test period: 12
#
# Training 1-step ahead model...
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
#
#   | Name         | Type          | Params | Mode  | FLOPs
# ---------------------------------------------------------------
# 0 | loss         | MSE           | 0      | train | 0
# 1 | padder_train | ConstantPad1d | 0      | train | 0
# 2 | scaler       | TemporalNorm  | 0      | train | 0
# 3 | mlp          | ModuleList    | 1.5 K  | train | 0
# 4 | out          | Linear        | 33     | train | 0
# ---------------------------------------------------------------
# 1.5 K     Trainable params
# 0         Non-trainable params
# 1.5 K     Total params
# 0.006     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 39.42it/s, v_num=10, train_loss_step=0.144, train_loss_epoch=0.144]
# `Trainer.fit` stopped: `max_steps=100` reached.
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 36.61it/s, v_num=10, train_loss_step=0.144, train_loss_epoch=0.144]
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 137.52it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 153.35it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 181.68it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 172.65it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 127.36it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 198.53it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 178.89it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 157.67it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 192.72it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 160.66it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 211.32it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 202.32it/s]
# Generating multi-step forecast...
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 199.88it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 168.66it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 224.40it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 236.97it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 237.69it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 199.63it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 217.81it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 216.86it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 225.13it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 226.90it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 239.63it/s]
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 240.51it/s]
# Training multi-output model...
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
#
#   | Name         | Type          | Params | Mode  | FLOPs
# ---------------------------------------------------------------
# 0 | loss         | MSE           | 0      | train | 0
# 1 | padder_train | ConstantPad1d | 0      | train | 0
# 2 | scaler       | TemporalNorm  | 0      | train | 0
# 3 | mlp          | ModuleList    | 1.5 K  | train | 0
# 4 | out          | Linear        | 396    | train | 0
# ---------------------------------------------------------------
# 1.9 K     Trainable params
# 0         Non-trainable params
# 1.9 K     Total params
# 0.007     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# 0         Total Flops
# Epoch 199: 100%|██████████| 1/1 [00:00<00:00, 45.16it/s, v_num=12, train_loss_step=0.267, train_loss_epoch=0.267]
# `Trainer.fit` stopped: `max_steps=200` reached.
# Epoch 199: 100%|██████████| 1/1 [00:00<00:00, 39.96it/s, v_num=12, train_loss_step=0.267, train_loss_epoch=0.267]
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 38.43it/s]
#
# ==================================================
# MAPE Results
# ==================================================
# 1-step MAPE:      0.5632%
# Multi-step MAPE:  0.5880%
# Multi-output MAPE: 0.7847%
# ==================================================

# %%
# View results
result_log.tail(15)
# Out:
#     unique_id         ds         y  MLP_1step_forecast  \
# 129   series1 1959-10-01  6.008813                 NaN
# 130   series1 1959-11-01  5.891644                 NaN
# 131   series1 1959-12-01  6.003887                 NaN
# 132   series1 1960-01-01  6.033086            6.016983
# 133   series1 1960-02-01  5.968708            6.018805
# 134   series1 1960-03-01  6.037871            6.120376
# 135   series1 1960-04-01  6.133398            6.108290
# 136   series1 1960-05-01  6.156979            6.120509
# 137   series1 1960-06-01  6.282267            6.287576
# 138   series1 1960-07-01  6.432940            6.427065
# 139   series1 1960-08-01  6.406880            6.462154
# 140   series1 1960-09-01  6.230481            6.288322
# 141   series1 1960-10-01  6.133398            6.120050
# 142   series1 1960-11-01  5.966147            6.016363
# 143   series1 1960-12-01  6.068426            6.084085
#
#      MLP_multistep_forecast  MLP_multioutput_forecast
# 129                     NaN                       NaN
# 130                     NaN                       NaN
# 131                     NaN                       NaN
# 132                6.016983                  6.007383
# 133                6.014024                  6.074298
# 134                6.131947                  6.110192
# 135                6.130157                  6.119928
# 136                6.139349                  6.169795
# 137                6.290723                  6.318142
# 138                6.419058                  6.448049
# 139                6.449401                  6.463607
# 140                6.302876                  6.334233
# 141                6.149910                  6.154840
# 142                6.034053                  6.054707
# 143                6.101750                  6.093011

# %% [markdown]
# # Summary
#
# This notebook demonstrates time series forecasting using **Nixtla's NeuralForecast MLP model**, which is a modern alternative to traditional deep learning frameworks like TensorFlow/Keras.
#
# ## Key Differences from Original Notebook:
#
# 1. **Data Format**: NeuralForecast requires data in long format with columns `unique_id`, `ds`, and `y`
# 2. **Model API**: Uses Nixtla's simplified API instead of Keras functional API
# 3. **Built-in Features**: NeuralForecast provides built-in scaling, early stopping, and validation
# 4. **Time Series Focus**: Designed specifically for time series forecasting
#
# ## Three Forecasting Approaches:
#
# 1. **1-step ahead**: Uses actual values for each prediction (best accuracy)
# 2. **Multi-step**: Iterative prediction using previous forecasts
# 3. **Multi-output**: Predicts all future values at once (model configured with `h=fh`)
#
# ## Resources:
# - NeuralForecast Documentation: https://nixtlaverse.nixtla.io/neuralforecast/
# - MLP Model: https://nixtlaverse.nixtla.io/neuralforecast/models.mlp.html

# %% [markdown]
# # Done!

# %% [markdown]
# # Bonus: Simple AutoMLP Example
#
# Let's create a simple AutoMLP model that automatically searches for the best hyperparameters.

# %%
import neuralforecast.auto as auto_module

# Get all attributes that start with 'Auto'
auto_models = [attr for attr in dir(auto_module) if attr.startswith('Auto')]

print("Available Auto Models:")
for model in sorted(auto_models):
    print(f"  - {model}")
# Out:
# Available Auto Models:
#   - AutoAutoformer
#   - AutoBiTCN
#   - AutoDLinear
#   - AutoDeepAR
#   - AutoDeepNPTS
#   - AutoDilatedRNN
#   - AutoFEDformer
#   - AutoGRU
#   - AutoHINT
#   - AutoInformer
#   - AutoKAN
#   - AutoLSTM
#   - AutoMLP
#   - AutoMLPMultivariate
#   - AutoNBEATS
#   - AutoNBEATSx
#   - AutoNHITS
#   - AutoNLinear
#   - AutoPatchTST
#   - AutoRMoK
#   - AutoRNN
#   - AutoSOFTS
#   - AutoStemGNN
#   - AutoTCN
#   - AutoTFT
#   - AutoTSMixer
#   - AutoTSMixerx
#   - AutoTiDE
#   - AutoTimeMixer
#   - AutoTimeXer
#   - AutoTimesNet
#   - AutoVanillaTransformer
#   - AutoXLinear
#   - Autoformer
#   - AutoiTransformer
#   - AutoxLSTM

# %%
# import automlp
from neuralforecast.auto import AutoMLP
# Create a simple AutoMLP model with default configuration
# This will automatically search for good hyperparameters
model_auto = AutoMLP(
    h=test_period,  # Forecast horizon (24 months)
    num_samples=3,  # Try 3 different configurations (keep it simple)
    cpus=1,
)

print("AutoMLP model created!")
print(f"Will test {model_auto.num_samples} different configurations")
# Out:
# AutoMLP model created!
# Will test 3 different configurations

# %%
# Train AutoMLP (this may take a few minutes as it tests multiple configurations)
print("Training AutoMLP...\n")

nf_auto = NeuralForecast(models=[model_auto], freq='MS')
# Provide validation size for hyperparameter tuning
nf_auto.fit(df=train, val_size=0)

print("\nAutoMLP training complete!")
# Out:
# (_train_tune pid=94371) /opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/ray/tune/integration/pytorch_lightning.py:198: `ray.tune.integration.pytorch_lightning.TuneReportCallback` is deprecated. Use `ray.tune.integration.pytorch_lightning.TuneReportCheckpointCallback` instead.
# (_train_tune pid=94371) Seed set to 3
# (_train_tune pid=94371) GPU available: True (mps), used: True
# (_train_tune pid=94371) TPU available: False, using: 0 TPU cores
# (_train_tune pid=94371) 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# (_train_tune pid=94371)
# (_train_tune pid=94371)   | Name         | Type          | Params | Mode  | FLOPs
# (_train_tune pid=94371) ---------------------------------------------------------------
# (_train_tune pid=94371) 0 | loss         | MAE           | 0      | train | 0
# (_train_tune pid=94371) 1 | padder_train | ConstantPad1d | 0      | train | 0
# (_train_tune pid=94371) 2 | scaler       | TemporalNorm  | 0      | train | 0
# (_train_tune pid=94371) 3 | mlp          | ModuleList    | 3.2 M  | train | 0
# (_train_tune pid=94371) 4 | out          | Linear        | 24.6 K | train | 0
# (_train_tune pid=94371) ---------------------------------------------------------------
# (_train_tune pid=94371) 3.2 M     Trainable params
# (_train_tune pid=94371) 0         Non-trainable params
# (_train_tune pid=94371) 3.2 M     Total params
# (_train_tune pid=94371) 12.993    Total estimated model params size (MB)
# (_train_tune pid=94371) 9         Modules in train mode
# (_train_tune pid=94371) 0         Modules in eval mode
# (_train_tune pid=94371) 0         Total Flops
# (_train_tune pid=94371) /opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# (_train_tune pid=94369)
# (_train_tune pid=94369) 3 | mlp          | ModuleList    | 813 K  | train | 0
# (_train_tune pid=94369) 825 K     Trainable params
# (_train_tune pid=94369) 825 K     Total params
# (_train_tune pid=94370)
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Sanity Checking DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Sanity Checking DataLoader 0: 100%|██████████| 1/1 [00:01<00:00,  0.93it/s]
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s]
# 2026-04-15 10:23:37,479	ERROR tune_controller.py:1326 -- Trial task failed for trial _train_tune_6c848_00001
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/ray/air/execution/_internal/event_manager.py", line 110, in resolve_future
#     result = ray.get(future)
#              ^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/ray/_private/auto_init_hook.py", line 22, in auto_init_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/ray/_private/client_mode_hook.py", line 107, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/ray/_private/worker.py", line 2980, in get
#     values, debugger_breakpoint = worker.get_objects(
#                                   ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/ray/_private/worker.py", line 1023, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError: ray::ImplicitFunc.train() (pid=94370, ip=127.0.0.1, actor_id=4591b5e8837cfc2e5508af2601000000, repr=_train_tune)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/ray/tune/trainable/trainable.py", line 324, in train
#     raise skipped from exception_cause(skipped)
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/ray/air/_internal/util.py", line 98, in run
#     self._ret = self._target(*self._args, **self._kwargs)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/ray/tune/trainable/function_trainable.py", line 44, in <lambda>
#     training_func=lambda: self._trainable_func(self.config),
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/ray/tune/trainable/function_trainable.py", line 249, in _trainable_func
#     output = fn()
#              ^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/ray/tune/trainable/util.py", line 130, in inner
#     return trainable(config, **fn_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/neuralforecast/common/_base_auto.py", line 202, in _train_tune
#     _ = self._fit_model(
#         ^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/neuralforecast/common/_base_auto.py", line 354, in _fit_model
#     model = model.fit(
#             ^^^^^^^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/neuralforecast/common/_base_model.py", line 1995, in fit
#     return self._fit(
#            ^^^^^^^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/neuralforecast/common/_base_model.py", line 610, in _fit
#     trainer.fit(model, datamodule=datamodule)
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/pytorch_lightning/trainer/trainer.py", line 584, in fit
#     call._call_and_handle_interrupt(
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/pytorch_lightning/trainer/call.py", line 49, in _call_and_handle_interrupt
#     return trainer_fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/pytorch_lightning/trainer/trainer.py", line 630, in _fit_impl
#     self._run(model, ckpt_path=ckpt_path, weights_only=weights_only)
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/pytorch_lightning/trainer/trainer.py", line 1079, in _run
#     results = self._run_stage()
#               ^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/pytorch_lightning/trainer/trainer.py", line 1123, in _run_stage
#     self.fit_loop.run()
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/pytorch_lightning/loops/fit_loop.py", line 217, in run
#     self.advance()
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/pytorch_lightning/loops/fit_loop.py", line 465, in advance
#     self.epoch_loop.run(self._data_fetcher)
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/pytorch_lightning/loops/training_epoch_loop.py", line 153, in run
#     self.advance(data_fetcher)
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/pytorch_lightning/loops/training_epoch_loop.py", line 352, in advance
#     batch_output = self.automatic_optimization.run(trainer.optimizers[0], batch_idx, kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/pytorch_lightning/loops/optimization/automatic.py", line 192, in run
#     self._optimizer_step(batch_idx, closure)
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/pytorch_lightning/loops/optimization/automatic.py", line 270, in _optimizer_step
#     call._call_lightning_module_hook(
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/pytorch_lightning/trainer/call.py", line 177, in _call_lightning_module_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/pytorch_lightning/core/module.py", line 1368, in optimizer_step
#     optimizer.step(closure=optimizer_closure)
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/pytorch_lightning/core/optimizer.py", line 154, in step
#     step_output = self._strategy.optimizer_step(self._optimizer, closure, **kwargs)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/pytorch_lightning/strategies/strategy.py", line 239, in optimizer_step
#     return self.precision_plugin.optimizer_step(optimizer, model=model, closure=closure, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/pytorch_lightning/plugins/precision/precision.py", line 123, in optimizer_step
#     return optimizer.step(closure=closure, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/torch/optim/lr_scheduler.py", line 166, in wrapper
#     return func.__get__(opt, opt.__class__)(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/torch/optim/optimizer.py", line 533, in wrapper
#     out = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/torch/optim/optimizer.py", line 81, in _use_grad
#     ret = func(*args, **kwargs)
#           ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/torch/optim/adam.py", line 227, in step
#     loss = closure()
#            ^^^^^^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/pytorch_lightning/plugins/precision/precision.py", line 109, in _wrap_closure
#     closure_result = closure()
#                      ^^^^^^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/pytorch_lightning/loops/optimization/automatic.py", line 146, in __call__
#     self._result = self.closure(*args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/torch/utils/_contextlib.py", line 124, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/pytorch_lightning/loops/optimization/automatic.py", line 131, in closure
#     step_output = self._step_fn()
#                   ^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/pytorch_lightning/loops/optimization/automatic.py", line 319, in _training_step
#     training_step_output = call._call_strategy_hook(trainer, "training_step", *kwargs.values())
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/pytorch_lightning/trainer/call.py", line 329, in _call_strategy_hook
#     output = fn(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/pytorch_lightning/strategies/strategy.py", line 391, in training_step
#     return self.lightning_module.training_step(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/neuralforecast/common/_base_model.py", line 1760, in training_step
#     self._create_windows(batch, step="train")
#   File "/opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/neuralforecast/common/_base_model.py", line 736, in _create_windows
#     raise Exception(
# Exception: Time series is too short for training, consider setting a smaller input size or set start_padding_enabled=True
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 0: 100%|██████████| 1/1 [00:03<00:00,  0.33it/s]
# Epoch 0: 100%|██████████| 1/1 [00:03<00:00,  0.33it/s, v_num=0, train_loss_step=269.0]
# Epoch 0: 100%|██████████| 1/1 [00:03<00:00,  0.33it/s, v_num=0, train_loss_step=269.0, train_loss_epoch=269.0]
# Epoch 7:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=269.0, train_loss_epoch=269.0]
# Epoch 7: 100%|██████████| 1/1 [00:00<00:00, 96.69it/s, v_num=0, train_loss_step=269.0, train_loss_epoch=269.0]
# Epoch 14: 100%|██████████| 1/1 [00:00<00:00, 100.94it/s, v_num=0, train_loss_step=44.40, train_loss_epoch=44.40]
# Epoch 14: 100%|██████████| 1/1 [00:00<00:00, 78.53it/s, v_num=0, train_loss_step=91.50, train_loss_epoch=44.40]
# Epoch 14: 100%|██████████| 1/1 [00:00<00:00, 73.83it/s, v_num=0, train_loss_step=91.50, train_loss_epoch=91.50]
# Epoch 14:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=91.50, train_loss_epoch=91.50]
# Epoch 15:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=91.50, train_loss_epoch=91.50]
# Epoch 21: 100%|██████████| 1/1 [00:00<00:00, 73.83it/s, v_num=0, train_loss_step=42.10, train_loss_epoch=42.10]
# Epoch 28: 100%|██████████| 1/1 [00:00<00:00, 97.55it/s, v_num=0, train_loss_step=63.70, train_loss_epoch=63.70]
# Epoch 28: 100%|██████████| 1/1 [00:00<00:00, 77.14it/s, v_num=0, train_loss_step=57.00, train_loss_epoch=63.70]
# Epoch 28: 100%|██████████| 1/1 [00:00<00:00, 71.81it/s, v_num=0, train_loss_step=57.00, train_loss_epoch=57.00]
# Epoch 35:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=37.10, train_loss_epoch=37.10]
# Epoch 43:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=36.90, train_loss_epoch=36.90]
# Sanity Checking: |          | 0/? [00:00<?, ?it/s] [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# Epoch 50:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=37.10, train_loss_epoch=37.10]
# Epoch 57:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=37.20, train_loss_epoch=37.20]
# Epoch 64:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=37.10, train_loss_epoch=37.10]
# Sanity Checking DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s] [repeated 2x across cluster]
# Epoch 71:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=36.50, train_loss_epoch=36.50]
# Epoch 78:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=36.50, train_loss_epoch=36.50]
# Epoch 78: 100%|██████████| 1/1 [00:00<00:00, 95.27it/s, v_num=0, train_loss_step=36.50, train_loss_epoch=36.50]
# Epoch 85: 100%|██████████| 1/1 [00:00<00:00, 93.20it/s, v_num=0, train_loss_step=37.10, train_loss_epoch=37.10]
# Epoch 85: 100%|██████████| 1/1 [00:00<00:00, 74.33it/s, v_num=0, train_loss_step=37.00, train_loss_epoch=37.10]
# Epoch 85: 100%|██████████| 1/1 [00:00<00:00, 69.86it/s, v_num=0, train_loss_step=37.00, train_loss_epoch=37.00]
# Epoch 93:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=36.60, train_loss_epoch=36.60]
# Epoch 93: 100%|██████████| 1/1 [00:00<00:00, 44.74it/s, v_num=0, train_loss_step=36.60, train_loss_epoch=36.60]
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 73.27it/s, v_num=0, train_loss_step=37.20, train_loss_epoch=37.00]
# (_train_tune pid=94369)
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 238.67it/s]
# Epoch 105: 100%|██████████| 1/1 [00:00<00:00, 93.12it/s, v_num=0, train_loss_step=37.10, train_loss_epoch=37.10, valid_loss=22.10]
# Epoch 105: 100%|██████████| 1/1 [00:00<00:00, 74.14it/s, v_num=0, train_loss_step=37.20, train_loss_epoch=37.10, valid_loss=22.10]
# Epoch 105: 100%|██████████| 1/1 [00:00<00:00, 69.62it/s, v_num=0, train_loss_step=37.20, train_loss_epoch=37.20, valid_loss=22.10]
# Epoch 106:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=37.20, train_loss_epoch=37.20, valid_loss=22.10]
# Epoch 112: 100%|██████████| 1/1 [00:00<00:00, 75.05it/s, v_num=0, train_loss_step=37.30, train_loss_epoch=37.10, valid_loss=22.10]
# Epoch 112: 100%|██████████| 1/1 [00:00<00:00, 70.92it/s, v_num=0, train_loss_step=37.30, train_loss_epoch=37.30, valid_loss=22.10]
# Epoch 113:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=37.30, train_loss_epoch=37.30, valid_loss=22.10]
# Epoch 119: 100%|██████████| 1/1 [00:00<00:00, 75.29it/s, v_num=0, train_loss_step=37.10, train_loss_epoch=37.10, valid_loss=22.10]
# Epoch 119: 100%|██████████| 1/1 [00:00<00:00, 71.53it/s, v_num=0, train_loss_step=37.10, train_loss_epoch=37.10, valid_loss=22.10]
# Epoch 120:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=37.10, train_loss_epoch=37.10, valid_loss=22.10]
# Epoch 126:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=36.70, train_loss_epoch=36.70, valid_loss=22.10]
# Epoch 132:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=36.80, train_loss_epoch=36.80, valid_loss=22.10]
# Sanity Checking DataLoader 0: 100%|██████████| 1/1 [00:02<00:00,  0.47it/s]
# Epoch 137: 100%|██████████| 1/1 [00:00<00:00, 60.49it/s, v_num=0, train_loss_step=37.40, train_loss_epoch=37.00, valid_loss=22.10]
# Epoch 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 137: 100%|██████████| 1/1 [00:00<00:00, 56.73it/s, v_num=0, train_loss_step=37.40, train_loss_epoch=37.40, valid_loss=22.10]
# Epoch 143: 100%|██████████| 1/1 [00:00<00:00, 78.49it/s, v_num=0, train_loss_step=37.50, train_loss_epoch=37.50, valid_loss=22.10]
# Epoch 149:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=36.90, train_loss_epoch=36.90, valid_loss=22.10]
# Epoch 3: 100%|██████████| 1/1 [00:00<00:00, 52.78it/s, v_num=0, train_loss_step=1.250, train_loss_epoch=1.250]
# Epoch 156:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=37.10, train_loss_epoch=37.10, valid_loss=22.10]
# Epoch 9:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=1.340, train_loss_epoch=1.340]
# Epoch 162:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=37.10, train_loss_epoch=37.10, valid_loss=22.10]
# Epoch 14:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.587, train_loss_epoch=0.587]
# Epoch 168:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=37.10, train_loss_epoch=37.10, valid_loss=22.10]
# Epoch 18:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.634, train_loss_epoch=0.634]
# Epoch 174: 100%|██████████| 1/1 [00:00<00:00, 70.45it/s, v_num=0, train_loss_step=37.10, train_loss_epoch=39.30, valid_loss=22.10]
# Epoch 23: 100%|██████████| 1/1 [00:00<00:00, 64.19it/s, v_num=0, train_loss_step=0.287, train_loss_epoch=0.287]
# Epoch 174: 100%|██████████| 1/1 [00:00<00:00, 61.18it/s, v_num=0, train_loss_step=37.10, train_loss_epoch=37.10, valid_loss=22.10]
# Epoch 28:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.293, train_loss_epoch=0.293]
# Epoch 32: 100%|██████████| 1/1 [00:00<00:00, 50.88it/s, v_num=0, train_loss_step=0.240, train_loss_epoch=0.240]
# Epoch 193:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=37.30, train_loss_epoch=37.30, valid_loss=22.10]
# Epoch 198: 100%|██████████| 1/1 [00:00<00:00, 58.91it/s, v_num=0, train_loss_step=37.00, train_loss_epoch=36.30, valid_loss=22.10]
# Epoch 42: 100%|██████████| 1/1 [00:00<00:00, 46.40it/s, v_num=0, train_loss_step=0.209, train_loss_epoch=0.129]
# Epoch 199: 100%|██████████| 1/1 [00:00<00:00, 62.55it/s, v_num=0, train_loss_step=37.10, train_loss_epoch=37.00, valid_loss=22.10]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 140.19it/s]
# Epoch 203:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=37.50, train_loss_epoch=37.50, valid_loss=19.30]
# Epoch 47:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.161, train_loss_epoch=0.161]
# Epoch 209: 100%|██████████| 1/1 [00:00<00:00, 83.53it/s, v_num=0, train_loss_step=37.60, train_loss_epoch=37.60, valid_loss=19.30]
# Epoch 215: 100%|██████████| 1/1 [00:00<00:00, 56.71it/s, v_num=0, train_loss_step=38.40, train_loss_epoch=38.40, valid_loss=19.30]
# Epoch 56: 100%|██████████| 1/1 [00:00<00:00, 54.36it/s, v_num=0, train_loss_step=0.176, train_loss_epoch=0.113]
# Epoch 57:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.176, train_loss_epoch=0.176]
# Epoch 223:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=36.70, train_loss_epoch=36.70, valid_loss=19.30]
# Epoch 230:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=37.10, train_loss_epoch=37.10, valid_loss=19.30]
# Epoch 67: 100%|██████████| 1/1 [00:00<00:00, 52.27it/s, v_num=0, train_loss_step=0.120, train_loss_epoch=0.120]
# Epoch 235: 100%|██████████| 1/1 [00:00<00:00, 89.74it/s, v_num=0, train_loss_step=38.60, train_loss_epoch=41.40, valid_loss=19.30]
# Epoch 72:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.131, train_loss_epoch=0.131]
# Epoch 243:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=37.20, train_loss_epoch=37.20, valid_loss=19.30]
# Epoch 249: 100%|██████████| 1/1 [00:00<00:00, 80.92it/s, v_num=0, train_loss_step=38.30, train_loss_epoch=36.80, valid_loss=19.30]
# Epoch 256:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=37.00, train_loss_epoch=37.00, valid_loss=19.30]
# Epoch 262: 100%|██████████| 1/1 [00:00<00:00, 87.39it/s, v_num=0, train_loss_step=37.10, train_loss_epoch=37.10, valid_loss=19.30]
# Epoch 269:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=36.80, train_loss_epoch=36.80, valid_loss=19.30]
# Epoch 275: 100%|██████████| 1/1 [00:00<00:00, 73.97it/s, v_num=0, train_loss_step=36.60, train_loss_epoch=36.60, valid_loss=19.30]
# Epoch 99: 100%|██████████| 1/1 [00:00<00:00, 56.11it/s, v_num=0, train_loss_step=0.0881, train_loss_epoch=0.0694]
# Epoch 102:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.159, train_loss_epoch=0.159, valid_loss=21.80]
# Epoch 275: 100%|██████████| 1/1 [00:00<00:00, 66.24it/s, v_num=0, train_loss_step=37.30, train_loss_epoch=37.30, valid_loss=19.30]
# Epoch 281:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=37.30, train_loss_epoch=37.30, valid_loss=19.30]
# Epoch 106:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.183, train_loss_epoch=0.183, valid_loss=21.80]
# Epoch 110:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.266, train_loss_epoch=0.266, valid_loss=21.80]
# Epoch 114:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.114, train_loss_epoch=0.114, valid_loss=21.80]
# Epoch 292: 100%|██████████| 1/1 [00:00<00:00, 94.71it/s, v_num=0, train_loss_step=37.30, train_loss_epoch=37.20, valid_loss=19.30]
# Epoch 299:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=37.20, train_loss_epoch=37.20, valid_loss=19.30]
# Epoch 299: 100%|██████████| 1/1 [00:00<00:00, 64.03it/s, v_num=0, train_loss_step=37.10, train_loss_epoch=37.20, valid_loss=19.30]
# Epoch 304:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=37.00, train_loss_epoch=37.00, valid_loss=22.00]
# Epoch 262: 100%|██████████| 1/1 [00:00<00:00, 74.75it/s, v_num=0, train_loss_step=37.20, train_loss_epoch=37.10, valid_loss=19.30] [repeated 10x across cluster]
# Epoch 129:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.112, train_loss_epoch=0.112, valid_loss=21.80]
# Epoch 133:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0919, train_loss_epoch=0.0919, valid_loss=21.80]
# Epoch 328: 100%|██████████| 1/1 [00:00<00:00, 78.76it/s, v_num=0, train_loss_step=37.30, train_loss_epoch=37.60, valid_loss=22.00]
# Epoch 341: 100%|██████████| 1/1 [00:00<00:00, 98.35it/s, v_num=0, train_loss_step=37.10, train_loss_epoch=37.10, valid_loss=22.00]
# Epoch 360: 100%|██████████| 1/1 [00:00<00:00, 72.48it/s, v_num=0, train_loss_step=36.70, train_loss_epoch=36.40, valid_loss=22.00]
# Epoch 367:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=37.10, train_loss_epoch=37.10, valid_loss=22.00]
# Epoch 373: 100%|██████████| 1/1 [00:00<00:00, 59.66it/s, v_num=0, train_loss_step=37.10, train_loss_epoch=37.10, valid_loss=22.00]
# Epoch 178: 100%|██████████| 1/1 [00:00<00:00, 59.05it/s, v_num=0, train_loss_step=0.147, train_loss_epoch=0.147, valid_loss=21.80]
# Epoch 381:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=37.70, train_loss_epoch=37.70, valid_loss=22.00]
# Epoch 388:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=37.20, train_loss_epoch=37.20, valid_loss=22.00]
# Validation: |          | 0/? [00:00<?, ?it/s] [repeated 6x across cluster]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s] [repeated 3x across cluster]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 150.85it/s] [repeated 3x across cluster]
# Epoch 179:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.147, train_loss_epoch=0.147, valid_loss=21.80] [repeated 15x across cluster]
# (_train_tune pid=94369)
#
# Epoch 406:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=37.50, train_loss_epoch=37.50, valid_loss=20.50]
# Epoch 207: 100%|██████████| 1/1 [00:00<00:00, 57.85it/s, v_num=0, train_loss_step=0.104, train_loss_epoch=0.169, valid_loss=20.90]
# Epoch 418:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=37.10, train_loss_epoch=37.10, valid_loss=20.50] [repeated 11x across cluster]
# Epoch 424: 100%|██████████| 1/1 [00:00<00:00, 66.37it/s, v_num=0, train_loss_step=36.80, train_loss_epoch=37.70, valid_loss=20.50]
# Epoch 217: 100%|██████████| 1/1 [00:00<00:00, 44.65it/s, v_num=0, train_loss_step=0.125, train_loss_epoch=0.125, valid_loss=20.90]
# Epoch 432:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=37.90, train_loss_epoch=37.90, valid_loss=20.50]
# Epoch 399: 100%|██████████| 1/1 [00:00<00:00, 88.57it/s, v_num=0, train_loss_step=37.10, train_loss_epoch=36.60, valid_loss=22.00] [repeated 2x across cluster]
# Epoch 228:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0862, train_loss_epoch=0.0862, valid_loss=20.90]
# Epoch 232: 100%|██████████| 1/1 [00:00<00:00, 64.59it/s, v_num=0, train_loss_step=0.0733, train_loss_epoch=0.0733, valid_loss=20.90]
# Epoch 450: 100%|██████████| 1/1 [00:00<00:00, 80.61it/s, v_num=0, train_loss_step=36.70, train_loss_epoch=36.70, valid_loss=20.50]
# Epoch 223:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0913, train_loss_epoch=0.0913, valid_loss=20.90] [repeated 23x across cluster]
# Epoch 457: 100%|██████████| 1/1 [00:00<00:00, 114.24it/s, v_num=0, train_loss_step=37.20, train_loss_epoch=37.20, valid_loss=20.50]
# Epoch 469: 100%|██████████| 1/1 [00:00<00:00, 70.16it/s, v_num=0, train_loss_step=37.30, train_loss_epoch=37.30, valid_loss=20.50] [repeated 3x across cluster]
# Epoch 252: 100%|██████████| 1/1 [00:00<00:00, 42.44it/s, v_num=0, train_loss_step=0.190, train_loss_epoch=0.190, valid_loss=20.90]
# Epoch 476: 100%|██████████| 1/1 [00:00<00:00, 90.41it/s, v_num=0, train_loss_step=37.10, train_loss_epoch=37.10, valid_loss=20.50]
# Epoch 483:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=37.00, train_loss_epoch=37.00, valid_loss=20.50]
# Epoch 490:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=36.60, train_loss_epoch=36.60, valid_loss=20.50]
# Epoch 490: 100%|██████████| 1/1 [00:00<00:00, 86.23it/s, v_num=0, train_loss_step=37.40, train_loss_epoch=37.40, valid_loss=20.50]
# Epoch 498:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=40.20, train_loss_epoch=40.20, valid_loss=20.50]
# Epoch 499: 100%|██████████| 1/1 [00:00<00:00, 30.81it/s, v_num=0, train_loss_step=37.00, train_loss_epoch=37.00, valid_loss=22.20]
# Epoch 469: 100%|██████████| 1/1 [00:00<00:00, 51.82it/s, v_num=0, train_loss_step=37.10, train_loss_epoch=37.10, valid_loss=20.50] [repeated 3x across cluster]
# Epoch 203:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.167, train_loss_epoch=0.167, valid_loss=20.90]
# (_train_tune pid=94369) `Trainer.fit` stopped: `max_steps=500` reached.
# (_train_tune pid=94370) /opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/ray/tune/integration/pytorch_lightning.py:198: `ray.tune.integration.pytorch_lightning.TuneReportCallback` is deprecated. Use `ray.tune.integration.pytorch_lightning.TuneReportCheckpointCallback` instead. [repeated 2x across cluster]
# (_train_tune pid=94370) Seed set to 1 [repeated 2x across cluster]
# (_train_tune pid=94370) GPU available: True (mps), used: True [repeated 2x across cluster]
# (_train_tune pid=94370) TPU available: False, using: 0 TPU cores [repeated 2x across cluster]
# (_train_tune pid=94370) 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform. [repeated 2x across cluster]
# (_train_tune pid=94370)   | Name         | Type          | Params | Mode  | FLOPs [repeated 2x across cluster]
# (_train_tune pid=94370) --------------------------------------------------------------- [repeated 4x across cluster]
# (_train_tune pid=94370) 0 | loss         | MAE           | 0      | train | 0     [repeated 2x across cluster]
# (_train_tune pid=94370) 1 | padder_train | ConstantPad1d | 0      | train | 0     [repeated 2x across cluster]
# (_train_tune pid=94370) 2 | scaler       | TemporalNorm  | 0      | train | 0     [repeated 2x across cluster]
# (_train_tune pid=94370) 4 | out          | Linear        | 12.3 K | train | 0     [repeated 2x across cluster]
# (_train_tune pid=94370) 0         Non-trainable params [repeated 2x across cluster]
# (_train_tune pid=94370) 2.398     Total estimated model params size (MB) [repeated 2x across cluster]
# (_train_tune pid=94370) 8         Modules in train mode [repeated 2x across cluster]
# (_train_tune pid=94370) 0         Modules in eval mode [repeated 2x across cluster]
# (_train_tune pid=94370) 0         Total Flops [repeated 2x across cluster]
# (_train_tune pid=94371) /opt/anaconda3/envs/nixtla/lib/python3.11/site-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead. [repeated 5x across cluster]
# (_train_tune pid=94370) 3 | mlp          | ModuleList    | 587 K  | train | 0
# (_train_tune pid=94370) 599 K     Trainable params
# (_train_tune pid=94370) 599 K     Total params
# Epoch 284:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.119, train_loss_epoch=0.119, valid_loss=20.90]
# Epoch 298:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.124, train_loss_epoch=0.124, valid_loss=20.90]
# Epoch 437: 100%|██████████| 1/1 [00:00<00:00, 56.14it/s, v_num=0, train_loss_step=38.00, train_loss_epoch=38.00, valid_loss=20.50] [repeated 2x across cluster]
# Epoch 302:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.285, train_loss_epoch=0.285, valid_loss=23.00]
# Epoch 316: 100%|██████████| 1/1 [00:00<00:00, 44.27it/s, v_num=0, train_loss_step=0.130, train_loss_epoch=0.130, valid_loss=23.00]
# Epoch 331:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.082, train_loss_epoch=0.082, valid_loss=23.00]
# Epoch 299: 100%|██████████| 1/1 [00:00<00:00, 41.95it/s, v_num=0, train_loss_step=0.283, train_loss_epoch=0.245, valid_loss=20.90] [repeated 2x across cluster]
# Epoch 345: 100%|██████████| 1/1 [00:00<00:00, 48.60it/s, v_num=0, train_loss_step=0.0929, train_loss_epoch=0.0562, valid_loss=23.00]
# Epoch 350: 100%|██████████| 1/1 [00:00<00:00, 43.35it/s, v_num=0, train_loss_step=0.0978, train_loss_epoch=0.0978, valid_loss=23.00]
# Epoch 360:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0505, train_loss_epoch=0.0505, valid_loss=23.00]
# Epoch 345: 100%|██████████| 1/1 [00:00<00:00, 46.49it/s, v_num=0, train_loss_step=0.0929, train_loss_epoch=0.0929, valid_loss=23.00] [repeated 13x across cluster]
# Epoch 379:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.111, train_loss_epoch=0.111, valid_loss=23.00]
# Epoch 398:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0936, train_loss_epoch=0.0936, valid_loss=23.00]
# Epoch 402:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.290, train_loss_epoch=0.290, valid_loss=21.60]
# Epoch 406:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0684, train_loss_epoch=0.0684, valid_loss=21.60]
# Epoch 410:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.127, train_loss_epoch=0.127, valid_loss=21.60]
# Epoch 414:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.131, train_loss_epoch=0.131, valid_loss=21.60]
# Epoch 419:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.148, train_loss_epoch=0.148, valid_loss=21.60]
# Epoch 423:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.239, train_loss_epoch=0.239, valid_loss=21.60]
# Epoch 427:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.104, train_loss_epoch=0.104, valid_loss=21.60]
# Validation: |          | 0/? [00:00<?, ?it/s] [repeated 8x across cluster]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s] [repeated 4x across cluster]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 146.31it/s] [repeated 4x across cluster]
# Epoch 351:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0978, train_loss_epoch=0.0978, valid_loss=23.00] [repeated 13x across cluster]
# Epoch 431: 100%|██████████| 1/1 [00:00<00:00, 51.24it/s, v_num=0, train_loss_step=0.102, train_loss_epoch=0.102, valid_loss=21.60]
# Epoch 436:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.119, train_loss_epoch=0.119, valid_loss=21.60]
# Epoch 440:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.119, train_loss_epoch=0.119, valid_loss=21.60]
# Epoch 269:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.216, train_loss_epoch=0.216, valid_loss=20.90] [repeated 3x across cluster]
# Epoch 444:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.186, train_loss_epoch=0.186, valid_loss=21.60]
# Epoch 448:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.107, train_loss_epoch=0.107, valid_loss=21.60]
# Epoch 274: 100%|██████████| 1/1 [00:00<00:00, 55.08it/s, v_num=0, train_loss_step=0.182, train_loss_epoch=0.106, valid_loss=20.90]
# Epoch 453:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0583, train_loss_epoch=0.0583, valid_loss=21.60]
# Epoch 463:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0715, train_loss_epoch=0.0715, valid_loss=21.60] [repeated 23x across cluster]
# Epoch 472:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0996, train_loss_epoch=0.0996, valid_loss=21.60]
# Epoch 477: 100%|██████████| 1/1 [00:00<00:00, 59.10it/s, v_num=0, train_loss_step=0.0674, train_loss_epoch=0.0674, valid_loss=21.60]
# Epoch 482:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0699, train_loss_epoch=0.0699, valid_loss=21.60]
# Epoch 491:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.184, train_loss_epoch=0.184, valid_loss=21.60]
# Epoch 495: 100%|██████████| 1/1 [00:00<00:00, 53.60it/s, v_num=0, train_loss_step=0.158, train_loss_epoch=0.158, valid_loss=21.60]
# Epoch 499: 100%|██████████| 1/1 [00:00<00:00, 44.37it/s, v_num=0, train_loss_step=0.153, train_loss_epoch=0.198, valid_loss=21.60]
# (_train_tune pid=94371)
# Epoch 503: 100%|██████████| 1/1 [00:00<00:00, 53.78it/s, v_num=0, train_loss_step=0.0883, train_loss_epoch=0.0883, valid_loss=23.00]
# Epoch 508:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0872, train_loss_epoch=0.0872, valid_loss=23.00]
# Epoch 512:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.138, train_loss_epoch=0.138, valid_loss=23.00]
# Epoch 526: 100%|██████████| 1/1 [00:00<00:00, 53.47it/s, v_num=0, train_loss_step=0.0632, train_loss_epoch=0.0632, valid_loss=23.00]
# Epoch 531:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.066, train_loss_epoch=0.066, valid_loss=23.00]
# Epoch 535:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0503, train_loss_epoch=0.0503, valid_loss=23.00]
# Epoch 539: 100%|██████████| 1/1 [00:00<00:00, 55.37it/s, v_num=0, train_loss_step=0.0698, train_loss_epoch=0.0698, valid_loss=23.00]
# Epoch 544:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0522, train_loss_epoch=0.0522, valid_loss=23.00]
# Epoch 548:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.150, train_loss_epoch=0.150, valid_loss=23.00]
# Epoch 552:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.126, train_loss_epoch=0.126, valid_loss=23.00]
# Epoch 399: 100%|██████████| 1/1 [00:00<00:00, 48.44it/s, v_num=0, train_loss_step=0.147, train_loss_epoch=0.260, valid_loss=23.00]
# Epoch 557:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.133, train_loss_epoch=0.133, valid_loss=23.00]
# Epoch 561:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.133, train_loss_epoch=0.133, valid_loss=23.00]
# Epoch 566: 100%|██████████| 1/1 [00:00<00:00, 60.11it/s, v_num=0, train_loss_step=0.0674, train_loss_epoch=0.101, valid_loss=23.00]
# Epoch 566: 100%|██████████| 1/1 [00:00<00:00, 57.78it/s, v_num=0, train_loss_step=0.0674, train_loss_epoch=0.0674, valid_loss=23.00] [repeated 6x across cluster]
# Epoch 581:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.080, train_loss_epoch=0.080, valid_loss=23.00]
# Epoch 591: 100%|██████████| 1/1 [00:00<00:00, 44.50it/s, v_num=0, train_loss_step=0.0528, train_loss_epoch=0.0539, valid_loss=23.00]
# Epoch 596:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.109, train_loss_epoch=0.109, valid_loss=23.00]
# Epoch 599: 100%|██████████| 1/1 [00:00<00:00, 43.54it/s, v_num=0, train_loss_step=0.111, train_loss_epoch=0.111, valid_loss=23.00]
# (_train_tune pid=94371)
# Epoch 604:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0793, train_loss_epoch=0.0793, valid_loss=26.40]
# Epoch 608:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0536, train_loss_epoch=0.0536, valid_loss=26.40]
# Epoch 618:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0857, train_loss_epoch=0.0857, valid_loss=26.40]
# Epoch 622:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0534, train_loss_epoch=0.0534, valid_loss=26.40]
# Epoch 626:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0491, train_loss_epoch=0.0491, valid_loss=26.40]
# Epoch 630: 100%|██████████| 1/1 [00:00<00:00, 52.99it/s, v_num=0, train_loss_step=0.0842, train_loss_epoch=0.0842, valid_loss=26.40]
# Epoch 635:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.261, train_loss_epoch=0.261, valid_loss=26.40]
# Epoch 644:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.146, train_loss_epoch=0.146, valid_loss=26.40]
# Validation: |          | 0/? [00:00<?, ?it/s] [repeated 4x across cluster]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s] [repeated 2x across cluster]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 130.16it/s] [repeated 2x across cluster]
# Epoch 592:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0528, train_loss_epoch=0.0528, valid_loss=23.00] [repeated 3x across cluster]
# Epoch 653:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0852, train_loss_epoch=0.0852, valid_loss=26.40]
# Epoch 659:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.177, train_loss_epoch=0.177, valid_loss=26.40] [repeated 3x across cluster]
# Epoch 663: 100%|██████████| 1/1 [00:00<00:00, 54.43it/s, v_num=0, train_loss_step=0.102, train_loss_epoch=0.102, valid_loss=26.40]
# Epoch 668:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.100, train_loss_epoch=0.100, valid_loss=26.40]
# Epoch 672:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.151, train_loss_epoch=0.151, valid_loss=26.40]
# Epoch 676:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.115, train_loss_epoch=0.115, valid_loss=26.40]
# Epoch 680: 100%|██████████| 1/1 [00:00<00:00, 51.59it/s, v_num=0, train_loss_step=0.0857, train_loss_epoch=0.0857, valid_loss=26.40]
# Epoch 649:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.388, train_loss_epoch=0.388, valid_loss=26.40] [repeated 8x across cluster]
# Epoch 685:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0934, train_loss_epoch=0.0934, valid_loss=26.40]
# Epoch 690: 100%|██████████| 1/1 [00:00<00:00, 52.99it/s, v_num=0, train_loss_step=0.0341, train_loss_epoch=0.0341, valid_loss=26.40]
# Epoch 699: 100%|██████████| 1/1 [00:00<00:00, 52.27it/s, v_num=0, train_loss_step=0.0705, train_loss_epoch=0.0675, valid_loss=26.40]
# Epoch 700: 100%|██████████| 1/1 [00:00<00:00, 57.50it/s, v_num=0, train_loss_step=0.0909, train_loss_epoch=0.0909, valid_loss=23.20]
# Epoch 705:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0596, train_loss_epoch=0.0596, valid_loss=23.20]
# Epoch 714:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0911, train_loss_epoch=0.0911, valid_loss=23.20]
# Epoch 718:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.113, train_loss_epoch=0.113, valid_loss=23.20]
# Epoch 722: 100%|██████████| 1/1 [00:00<00:00, 53.07it/s, v_num=0, train_loss_step=0.094, train_loss_epoch=0.094, valid_loss=23.20]
# Epoch 728:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0557, train_loss_epoch=0.0557, valid_loss=23.20]
# Epoch 737:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0623, train_loss_epoch=0.0623, valid_loss=23.20]
# Epoch 752: 100%|██████████| 1/1 [00:00<00:00, 55.90it/s, v_num=0, train_loss_step=0.0901, train_loss_epoch=0.0901, valid_loss=23.20]
# Epoch 757:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.102, train_loss_epoch=0.102, valid_loss=23.20]
# Epoch 761: 100%|██████████| 1/1 [00:00<00:00, 52.74it/s, v_num=0, train_loss_step=0.0648, train_loss_epoch=0.0648, valid_loss=23.20]
# Epoch 766: 100%|██████████| 1/1 [00:00<00:00, 47.72it/s, v_num=0, train_loss_step=0.0706, train_loss_epoch=0.0573, valid_loss=23.20]
# Epoch 766:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0706, train_loss_epoch=0.0706, valid_loss=23.20]
# Epoch 767:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0706, train_loss_epoch=0.0706, valid_loss=23.20]
# Epoch 781:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0833, train_loss_epoch=0.0833, valid_loss=23.20]
# Epoch 785:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.216, train_loss_epoch=0.216, valid_loss=23.20]
# Epoch 789:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0657, train_loss_epoch=0.0657, valid_loss=23.20]
# Epoch 799: 100%|██████████| 1/1 [00:00<00:00, 43.45it/s, v_num=0, train_loss_step=0.159, train_loss_epoch=0.0633, valid_loss=23.20]
# Epoch 766: 100%|██████████| 1/1 [00:00<00:00, 46.15it/s, v_num=0, train_loss_step=0.0706, train_loss_epoch=0.0706, valid_loss=23.20] [repeated 6x across cluster]
# (_train_tune pid=94371)
# (_train_tune pid=94371)
# (_train_tune pid=94371)
# Epoch 803:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.137, train_loss_epoch=0.137, valid_loss=27.10]
# Epoch 806: 100%|██████████| 1/1 [00:00<00:00, 37.35it/s, v_num=0, train_loss_step=0.159, train_loss_epoch=0.159, valid_loss=27.10]
# Epoch 811:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.203, train_loss_epoch=0.203, valid_loss=27.10]
# Epoch 820:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.213, train_loss_epoch=0.213, valid_loss=27.10]
# Epoch 829:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.101, train_loss_epoch=0.101, valid_loss=27.10]
# Epoch 838:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.105, train_loss_epoch=0.105, valid_loss=27.10]
# Epoch 842:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0448, train_loss_epoch=0.0448, valid_loss=27.10]
# Epoch 848:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.124, train_loss_epoch=0.124, valid_loss=27.10]
# Epoch 852: 100%|██████████| 1/1 [00:00<00:00, 54.47it/s, v_num=0, train_loss_step=0.040, train_loss_epoch=0.040, valid_loss=27.10]
# Epoch 857:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0658, train_loss_epoch=0.0658, valid_loss=27.10]
# Validation: |          | 0/? [00:00<?, ?it/s] [repeated 4x across cluster]
# Validation DataLoader 0:   0%|          | 0/1 [00:00<?, ?it/s] [repeated 2x across cluster]
# Validation DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 127.26it/s] [repeated 2x across cluster]
# Epoch 807:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.159, train_loss_epoch=0.159, valid_loss=27.10] [repeated 5x across cluster]
# Epoch 866:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.120, train_loss_epoch=0.120, valid_loss=27.10]
# Epoch 795:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.068, train_loss_epoch=0.068, valid_loss=23.20]
# Epoch 885: 100%|██████████| 1/1 [00:00<00:00, 54.11it/s, v_num=0, train_loss_step=0.0674, train_loss_epoch=0.0674, valid_loss=27.10]
# Epoch 890:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0504, train_loss_epoch=0.0504, valid_loss=27.10]
# Epoch 894:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0447, train_loss_epoch=0.0447, valid_loss=27.10]
# Epoch 898: 100%|██████████| 1/1 [00:00<00:00, 44.83it/s, v_num=0, train_loss_step=0.103, train_loss_epoch=0.0457, valid_loss=27.10]
# Epoch 881:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0752, train_loss_epoch=0.0752, valid_loss=27.10] [repeated 14x across cluster]
# Epoch 899: 100%|██████████| 1/1 [00:00<00:00, 43.31it/s, v_num=0, train_loss_step=0.0608, train_loss_epoch=0.103, valid_loss=27.10]
# Epoch 903:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.114, train_loss_epoch=0.114, valid_loss=26.90]
# Epoch 913: 100%|██████████| 1/1 [00:00<00:00, 54.49it/s, v_num=0, train_loss_step=0.0958, train_loss_epoch=0.0958, valid_loss=26.90]
# Epoch 918:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0597, train_loss_epoch=0.0597, valid_loss=26.90]
# Epoch 922:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.122, train_loss_epoch=0.122, valid_loss=26.90]
# Epoch 931:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0629, train_loss_epoch=0.0629, valid_loss=26.90]
# Epoch 935:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.210, train_loss_epoch=0.210, valid_loss=26.90]
# Epoch 939:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.150, train_loss_epoch=0.150, valid_loss=26.90]
# Epoch 944:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.106, train_loss_epoch=0.106, valid_loss=26.90]
# Epoch 949: 100%|██████████| 1/1 [00:00<00:00, 60.52it/s, v_num=0, train_loss_step=0.0722, train_loss_epoch=0.0722, valid_loss=26.90]
# Epoch 955:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.117, train_loss_epoch=0.117, valid_loss=26.90]
# Epoch 959: 100%|██████████| 1/1 [00:00<00:00, 44.66it/s, v_num=0, train_loss_step=0.0955, train_loss_epoch=0.0562, valid_loss=26.90]
# Epoch 964:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.114, train_loss_epoch=0.114, valid_loss=26.90]
# Epoch 968:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0879, train_loss_epoch=0.0879, valid_loss=26.90]
# Epoch 972:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0522, train_loss_epoch=0.0522, valid_loss=26.90]
# Epoch 976: 100%|██████████| 1/1 [00:00<00:00, 51.27it/s, v_num=0, train_loss_step=0.0643, train_loss_epoch=0.0643, valid_loss=26.90]
# Epoch 980:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0497, train_loss_epoch=0.0497, valid_loss=26.90]
# Epoch 984: 100%|██████████| 1/1 [00:00<00:00, 44.70it/s, v_num=0, train_loss_step=0.117, train_loss_epoch=0.0575, valid_loss=26.90]
# Epoch 989:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.035, train_loss_epoch=0.035, valid_loss=26.90]
# Epoch 993:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0462, train_loss_epoch=0.0462, valid_loss=26.90]
# Epoch 997:   0%|          | 0/1 [00:00<?, ?it/s, v_num=0, train_loss_step=0.0521, train_loss_epoch=0.0521, valid_loss=26.90]
# 2026-04-15 10:24:05,006	INFO tune.py:1001 -- Wrote the latest version of all result files and experiment state to '/Users/a02291312/ray_results/_train_tune_2026-04-15_10-23-23' in 0.0051s.
# 2026-04-15 10:24:05,008	ERROR tune.py:1029 -- Trials did not complete: [_train_tune_6c848_00001]
# (_train_tune pid=94371) `Trainer.fit` stopped: `max_steps=1000` reached.
# Seed set to 5
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
#
#   | Name         | Type          | Params | Mode  | FLOPs
# ---------------------------------------------------------------
# 0 | loss         | MAE           | 0      | eval  | 0
# 1 | padder_train | ConstantPad1d | 0      | train | 0
# 2 | scaler       | TemporalNorm  | 0      | train | 0
# 3 | mlp          | ModuleList    | 813 K  | train | 0
# 4 | out          | Linear        | 12.3 K | train | 0
# ---------------------------------------------------------------
# 825 K     Trainable params
# 0         Non-trainable params
# 825 K     Total params
# 3.301     Total estimated model params size (MB)
# 8         Modules in train mode
# 1         Modules in eval mode
# 0         Total Flops
# Epoch 999: 100%|██████████| 1/1 [00:00<00:00, 43.34it/s, v_num=0, train_loss_step=0.0582, train_loss_epoch=0.0327, valid_loss=26.90]
# Epoch 999: 100%|██████████| 1/1 [00:00<00:00, 24.19it/s, v_num=0, train_loss_step=0.0582, train_loss_epoch=0.0582, valid_loss=27.20]
# Epoch 499: 100%|██████████| 1/1 [00:00<00:00, 49.09it/s, v_num=14, train_loss_step=52.70, train_loss_epoch=52.70]
# `Trainer.fit` stopped: `max_steps=500` reached.
# Epoch 499: 100%|██████████| 1/1 [00:00<00:00, 44.99it/s, v_num=14, train_loss_step=52.70, train_loss_epoch=52.70]
#
# AutoMLP training complete!

# %%
# Make predictions with AutoMLP
forecast_auto = nf_auto.predict(df=train)

# Add AutoMLP predictions to dataframe
data['AutoMLP_forecast'] = np.nan
data.loc[train_period:, 'AutoMLP_forecast'] = forecast_auto['AutoMLP'].values

# Calculate MAPE for AutoMLP
mape_auto = mean_absolute_percentage_error(actual_test, data.loc[train_period:, 'AutoMLP_forecast'])

print("=" * 50)
print("AutoMLP Performance")
print("=" * 50)
print(f"AutoMLP forecast MAPE: {mape_auto:.4f}%")
print("=" * 50)
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  7.76it/s]
# ==================================================
# AutoMLP Performance
# ==================================================
# AutoMLP forecast MAPE: 17.1189%
# ==================================================

# %%
# Visualize AutoMLP forecast compared to manual MLP
plt.figure(figsize=(15, 5))
plt.plot(data['ds'], data['y'], label='Actual', linewidth=2)
plt.plot(data.iloc[train_period:]['ds'], data.iloc[train_period:]['MLP_multioutput_forecast'],
         label='Manual MLP Forecast', linestyle='--', marker='o', alpha=0.7)
plt.plot(data.iloc[train_period:]['ds'], data.iloc[train_period:]['AutoMLP_forecast'],
         label='AutoMLP Forecast', linestyle='--', marker='s', alpha=0.7)
plt.axvline(x=data.iloc[train_period]['ds'], color='red', linestyle='--', alpha=0.5, label='Train/Test Split')
plt.title('Manual MLP vs AutoMLP Forecast Comparison')
plt.xlabel('Date')
plt.ylabel('Number of Passengers')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Final comparison: All models
comparison_all = pd.DataFrame({
    'Model': ['1-step', 'Multi-step', 'Multi-output (Manual MLP)', 'AutoMLP'],
    'MAPE (%)': [mape_1step, mape_multistep, mape_multioutput, mape_auto]
})

comparison_all = comparison_all.sort_values('MAPE (%)')

print("=" * 60)
print("Final MAPE Comparison - All Models")
print("=" * 60)
print(comparison_all.to_string(index=False))
print("=" * 60)

# Visualize
plt.figure(figsize=(12, 6))
colors = ['blue', 'orange', 'green', 'red']
bars = plt.bar(comparison_all['Model'], comparison_all['MAPE (%)'], color=colors)
plt.title('MAPE Comparison: All Forecasting Methods', fontsize=14, fontweight='bold')
plt.ylabel('MAPE (%)', fontsize=12)
plt.xlabel('Model Type', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.grid(True, alpha=0.3, axis='y')

# Add value labels on bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{height:.2f}%',
             ha='center', va='bottom', fontsize=10)

plt.tight_layout()
plt.show()

comparison_all
# Out:
# ============================================================
# Final MAPE Comparison - All Models
# ============================================================
#                     Model  MAPE (%)
#                    1-step  3.642582
#                Multi-step  7.052755
# Multi-output (Manual MLP)  9.649595
#                   AutoMLP 17.118948
# ============================================================
#                        Model   MAPE (%)
# 0                     1-step   3.642582
# 1                 Multi-step   7.052755
# 2  Multi-output (Manual MLP)   9.649595
# 3                    AutoMLP  17.118948
